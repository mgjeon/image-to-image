# %% [markdown]
# # SDO
#
# - http://jsoc.stanford.edu/
# - https://www.lmsal.com/sdodocs/doc/dcur/SDOD0060.zip/zip/entry/

# %% [markdown]
# ## sunpy Fido

# %%
from sunpy.net import Fido, attrs as a
import astropy.units as u

# %%
result = Fido.search(
    a.Time('2020-01-01T00:00:00', '2020-01-01T00:01:00'),
    a.jsoc.Series('aia.lev1_euv_12s'),
    a.jsoc.Segment('image'),
    a.AttrOr([a.Wavelength(wl) for wl in [94, 131, 171, 193, 211, 304, 335]*u.AA]),
    a.Sample(1*u.day),
    a.jsoc.Notify("mgjeon@khu.ac.kr")
)

# %%
result.show()
# Out:
# <sunpy.net.fido_factory.UnifiedResponse object>
# Results from 7 Providers:
#
# 1 Results from the JSOCClient:
# Source: http://jsoc.stanford.edu
#
#        T_REC         ...                   image
# -------------------- ... -----------------------------------------
# 2019-12-31T23:59:59Z ... /SUM36/D1248942730/S00000/image_lev1.fits
#
# 1 Results from the JSOCClient:
# Source: http://jsoc.stanford.edu
#
#        T_REC         ...                   image
# -------------------- ... -----------------------------------------
# 2019-12-31T23:59:59Z ... /SUM36/D1248942742/S00000/image_lev1.fits
#
# 1 Results from the JSOCClient:
# Source: http://jsoc.stanford.edu
#
#        T_REC         ...                   image
# -------------------- ... -----------------------------------------
# 2019-12-31T23:59:59Z ... /SUM46/D1248942744/S00000/image_lev1.fits
#
# 1 Results from the JSOCClient:
# Source: http://jsoc.stanford.edu
#
#        T_REC         ...                   image
# -------------------- ... -----------------------------------------
# 2019-12-31T23:59:59Z ... /SUM45/D1248942737/S00000/image_lev1.fits
#
# 1 Results from the JSOCClient:
# Source: http://jsoc.stanford.edu
#
#        T_REC         ...                   image
# -------------------- ... -----------------------------------------
# 2019-12-31T23:59:59Z ... /SUM55/D1248846155/S00000/image_lev1.fits
#
# 1 Results from the JSOCClient:
# Source: http://jsoc.stanford.edu
#
#        T_REC         ...                   image
# -------------------- ... -----------------------------------------
# 2019-12-31T23:59:59Z ... /SUM55/D1248942740/S00000/image_lev1.fits
#
# 1 Results from the JSOCClient:
# Source: http://jsoc.stanford.edu
#
#        T_REC         ...                   image
# -------------------- ... -----------------------------------------
# 2019-12-31T23:59:59Z ... /SUM46/D1248942731/S00000/image_lev1.fits

# %%
download_files = Fido.fetch(result)

# %%
for file in download_files:
    print(file)
# Out:
# /home/mgj/sunpy/data/aia.lev1_euv_12s.2020-01-01T000001Z.94.image_lev1.fits
# /home/mgj/sunpy/data/aia.lev1_euv_12s.2020-01-01T000008Z.131.image_lev1.fits
# /home/mgj/sunpy/data/aia.lev1_euv_12s.2020-01-01T000010Z.171.image_lev1.fits
# /home/mgj/sunpy/data/aia.lev1_euv_12s.2020-01-01T000006Z.193.image_lev1.fits
# /home/mgj/sunpy/data/aia.lev1_euv_12s.2019-12-31T235959Z.211.image_lev1.fits
# /home/mgj/sunpy/data/aia.lev1_euv_12s.2020-01-01T000007Z.304.image_lev1.fits
# /home/mgj/sunpy/data/aia.lev1_euv_12s.2020-01-01T000002Z.335.image_lev1.fits

# %%
from astropy.time import Time

# %%
t_obs = "2020-01-01T00:00:00.57Z"
t_obs = Time(t_obs, format='isot', scale='utc')
t_obs
# Out:
# <Time object: scale='utc' format='isot' value=2020-01-01T00:00:00.570>

# %%
t_obs.tai
# Out:
# <Time object: scale='tai' format='isot' value=2020-01-01T00:00:37.570>

# %%
t_obs_lower_precision = Time(t_obs, precision=0)
t_obs_lower_precision.isot
# Out:
# '2020-01-01T00:00:01'

# %% [markdown]
# ## drms

# %%
import drms

# %%
client = drms.Client(email="mgjeon@khu.ac.kr")

# %%
date = Time("2020-01-01T00:00:00").to_datetime()
date
# Out:
# datetime.datetime(2020, 1, 1, 0, 0)

# %%
date.isoformat('_', timespec='seconds')
# Out:
# '2020-01-01_00:00:00'

# %%
time_param = '%sZ' % date.isoformat('_', timespec='seconds')
time_param
# Out:
# '2020-01-01_00:00:00Z'

# %% [markdown]
# ### EUV

# %%
ds_euv = 'aia.lev1_euv_12s[%s][%s]{image}' % (time_param, ','.join(['94', '131', '171', '193', '211', '304', '335']))
ds_euv
# Out:
# 'aia.lev1_euv_12s[2020-01-01_00:00:00Z][94,131,171,193,211,304,335]{image}'

# %%
keys = client.keys(ds_euv)
keys
# Out:
# ['T_REC',
#  'T_OBS',
#  'WAVELNTH',
#  'DATE',
#  'FSN',
#  'EXPTIME',
#  'QUALITY',
#  'ORIGIN',
#  'TELESCOP',
#  'INSTRUME',
#  'DATE__OBS',
#  'DATE-OBS',
#  'CAMERA',
#  'IMG_TYPE',
#  'EXPSDEV',
#  'INT_TIME',
#  'WAVEUNIT',
#  'WAVE_STR',
#  'FID',
#  'QUALLEV0',
#  'TOTVALS',
#  'DATAVALS',
#  'MISSVALS',
#  'PERCENTD',
#  'DATAMIN',
#  'DATAMAX',
#  'DATAMEDN',
#  'DATAMEAN',
#  'DATARMS',
#  'DATASKEW',
#  'DATAKURT',
#  'DATACENT',
#  'DATAP01',
#  'DATAP10',
#  'DATAP25',
#  'DATAP75',
#  'DATAP90',
#  'DATAP95',
#  'DATAP98',
#  'DATAP99',
#  'NSATPIX',
#  'OSCNMEAN',
#  'OSCNRMS',
#  'FLAT_REC',
#  'NSPIKES',
#  'CTYPE1',
#  'CUNIT1',
#  'CRVAL1',
#  'CDELT1',
#  'CRPIX1',
#  'CTYPE2',
#  'CUNIT2',
#  'CRVAL2',
#  'CDELT2',
#  'CRPIX2',
#  'CROTA2',
#  'R_SUN',
#  'MPO_REC',
#  'INST_ROT',
#  'IMSCL_MP',
#  'X0_MP',
#  'Y0_MP',
#  'ASD_REC',
#  'SAT_Y0',
#  'SAT_Z0',
#  'SAT_ROT',
#  'ACS_MODE',
#  'ACS_ECLP',
#  'ACS_SUNP',
#  'ACS_SAFE',
#  'ACS_CGT',
#  'ORB_REC',
#  'DSUN_REF',
#  'DSUN_OBS',
#  'RSUN_REF',
#  'RSUN_OBS',
#  'GAEX_OBS',
#  'GAEY_OBS',
#  'GAEZ_OBS',
#  'HAEX_OBS',
#  'HAEY_OBS',
#  'HAEZ_OBS',
#  'OBS_VR',
#  'OBS_VW',
#  'OBS_VN',
#  'CAR_ROT',
#  'CRLT_OBS',
#  'CRLN_OBS',
#  'HGLN_OBS',
#  'HGLT_OBS',
#  'ROI_NWIN',
#  'CALVER32',
#  'ROI_SUM',
#  'ROI_NAX1',
#  'ROI_NAY1',
#  'ROI_LLX1',
#  'ROI_LLY1',
#  'ROI_NAX2',
#  'ROI_NAY2',
#  'ROI_LLX2',
#  'ROI_LLY2',
#  'PIXLUNIT',
#  'DN_GAIN',
#  'EFF_AREA',
#  'EFF_AR_V',
#  'TEMPCCD',
#  'TEMPGT',
#  'TEMPSMIR',
#  'TEMPFPAD',
#  'ISPSNAME',
#  'ISPPKTIM',
#  'ISPPKTVN',
#  'AIVNMST',
#  'AIMGOTS',
#  'ASQHDR',
#  'ASQTNUM',
#  'ASQFSN',
#  'AIAHFSN',
#  'AECDELAY',
#  'AIAECTI',
#  'AIASEN',
#  'AIFDBID',
#  'AIMGOTSS',
#  'AIFCPS',
#  'AIFTSWTH',
#  'AIFRMLID',
#  'AIFTSID',
#  'AIHISMXB',
#  'AIHIS192',
#  'AIHIS348',
#  'AIHIS604',
#  'AIHIS860',
#  'AIFWEN',
#  'AIMGSHCE',
#  'AECTYPE',
#  'AECMODE',
#  'AISTATE',
#  'AIAECENF',
#  'AIFILTYP',
#  'AIMSHOBC',
#  'AIMSHOBE',
#  'AIMSHOTC',
#  'AIMSHOTE',
#  'AIMSHCBC',
#  'AIMSHCBE',
#  'AIMSHCTC',
#  'AIMSHCTE',
#  'AICFGDL1',
#  'AICFGDL2',
#  'AICFGDL3',
#  'AICFGDL4',
#  'AIFOENFL',
#  'AIMGFSN',
#  'AIMGTYP',
#  'AIAWVLEN',
#  'AIAGP1',
#  'AIAGP2',
#  'AIAGP3',
#  'AIAGP4',
#  'AIAGP5',
#  'AIAGP6',
#  'AIAGP7',
#  'AIAGP8',
#  'AIAGP9',
#  'AIAGP10',
#  'AGT1SVY',
#  'AGT1SVZ',
#  'AGT2SVY',
#  'AGT2SVZ',
#  'AGT3SVY',
#  'AGT3SVZ',
#  'AGT4SVY',
#  'AGT4SVZ',
#  'AIMGSHEN',
#  'KEYWDDOC',
#  'LVL_NUM',
#  'T_REC_step',
#  'T_REC_epoch',
#  'T_REC_index']

# %%
header, segment = client.query(ds_euv, key=','.join(keys), seg='image')

# %%
header
# Out:
#                   T_REC                    T_OBS  WAVELNTH  \
# 0  2019-12-31T23:59:59Z  2020-01-01T00:00:00.57Z        94
# 1  2019-12-31T23:59:59Z  2020-01-01T00:00:08.07Z       131
# 2  2019-12-31T23:59:59Z  2020-01-01T00:00:10.35Z       171
# 3  2019-12-31T23:59:59Z  2020-01-01T00:00:05.84Z       193
# 4  2019-12-31T23:59:59Z  2019-12-31T23:59:59.08Z       211
# 5  2019-12-31T23:59:59Z  2020-01-01T00:00:06.58Z       304
# 6  2019-12-31T23:59:59Z  2020-01-01T00:00:02.09Z       335
#
#                    DATE        FSN   EXPTIME  QUALITY        ORIGIN TELESCOP  \
# 0  2020-01-07T15:05:09Z  206235994  2.900822        0  SDO/JSOC-SDP  SDO/AIA
# 1  2020-01-07T15:05:09Z  206235999  2.901311        0  SDO/JSOC-SDP  SDO/AIA
# 2  2020-01-07T15:05:09Z  206236000  2.000154        0  SDO/JSOC-SDP  SDO/AIA
# 3  2020-01-07T15:05:09Z  206235997  2.000073        0  SDO/JSOC-SDP  SDO/AIA
# 4  2020-01-06T15:11:11Z  206235993  2.900796        0  SDO/JSOC-SDP  SDO/AIA
# 5  2020-01-07T15:05:09Z  206235998  2.902044        0  SDO/JSOC-SDP  SDO/AIA
# 6  2020-01-07T15:05:09Z  206235995  2.900793        0  SDO/JSOC-SDP  SDO/AIA
#
#   INSTRUME  ... AGT3SVY AGT3SVZ  AGT4SVY AGT4SVZ  AIMGSHEN  \
# 0    AIA_4  ...       0       1       58     122         4
# 1    AIA_1  ...      -3       0       56     121         4
# 2    AIA_3  ...      -1       0       57     121        13
# 3    AIA_2  ...       2       0       60     121        12
# 4    AIA_2  ...       2       0       60     121         4
# 5    AIA_4  ...       1       0       59     121        12
# 6    AIA_1  ...      -2       1       56     122        13
#
#                                             KEYWDDOC LVL_NUM T_REC_step  \
# 0  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 1  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 2  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 3  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 4  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 5  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 6  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
#
#                T_REC_epoch  T_REC_index
# 0  1993.01.01_00:00:04_TAI     70999203
# 1  1993.01.01_00:00:04_TAI     70999203
# 2  1993.01.01_00:00:04_TAI     70999203
# 3  1993.01.01_00:00:04_TAI     70999203
# 4  1993.01.01_00:00:04_TAI     70999203
# 5  1993.01.01_00:00:04_TAI     70999203
# 6  1993.01.01_00:00:04_TAI     70999203
#
# [7 rows x 179 columns]

# %%
segment
# Out:
#                                        image
# 0  /SUM36/D1248942730/S00000/image_lev1.fits
# 1  /SUM36/D1248942742/S00000/image_lev1.fits
# 2  /SUM46/D1248942744/S00000/image_lev1.fits
# 3  /SUM45/D1248942737/S00000/image_lev1.fits
# 4  /SUM55/D1248846155/S00000/image_lev1.fits
# 5  /SUM55/D1248942740/S00000/image_lev1.fits
# 6  /SUM46/D1248942731/S00000/image_lev1.fits

# %%
from datetime import timedelta

# %%
t = date - timedelta(seconds=24)
t
# Out:
# datetime.datetime(2019, 12, 31, 23, 59, 36)

# %%
t.isoformat('_', timespec='seconds')
# Out:
# '2019-12-31_23:59:36'

# %%
(t + timedelta(seconds=48)).isoformat('_', timespec='seconds')
# Out:
# '2020-01-01_00:00:24'

# %%
for wl in ['94', '131', '171', '193', '211', '304', '335']:
    euv_ds = 'aia.lev1_euv_12s[%sZ/48s][%s]{image}' % (
                    t.replace(tzinfo=None).isoformat('_', timespec='seconds'), wl)
    euv_keys = client.keys(euv_ds)
    euv_header, euv_segment = client.query(euv_ds, key=','.join(euv_keys), seg='image')
    print(euv_header)
# Out:
#                   T_REC                    T_OBS  WAVELNTH  \
# 0  2019-12-31T23:59:35Z  2019-12-31T23:59:36.57Z        94
# 1  2019-12-31T23:59:47Z  2019-12-31T23:59:48.57Z        94
# 2  2019-12-31T23:59:59Z  2020-01-01T00:00:00.57Z        94
# 3  2020-01-01T00:00:11Z  2020-01-01T00:00:12.57Z        94
#
#                    DATE        FSN   EXPTIME  QUALITY        ORIGIN TELESCOP  \
# 0  2020-01-06T15:11:11Z  206235978  2.900829        0  SDO/JSOC-SDP  SDO/AIA
# 1  2020-01-06T15:11:11Z  206235986  2.900828        0  SDO/JSOC-SDP  SDO/AIA
# 2  2020-01-07T15:05:09Z  206235994  2.900822        0  SDO/JSOC-SDP  SDO/AIA
# 3  2020-01-07T15:05:09Z  206236002  2.900828        0  SDO/JSOC-SDP  SDO/AIA
#
#   INSTRUME  ... AGT3SVY AGT3SVZ  AGT4SVY AGT4SVZ  AIMGSHEN  \
# 0    AIA_4  ...       0       0       58     121         4
# 1    AIA_4  ...       0       1       59     122         4
# 2    AIA_4  ...       0       1       58     122         4
# 3    AIA_4  ...      -1       0       57     121         4
#
#                                             KEYWDDOC LVL_NUM T_REC_step  \
# 0  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 1  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 2  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 3  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
#
#                T_REC_epoch  T_REC_index
# 0  1993.01.01_00:00:04_TAI     70999201
# 1  1993.01.01_00:00:04_TAI     70999202
# 2  1993.01.01_00:00:04_TAI     70999203
# 3  1993.01.01_00:00:04_TAI     70999204
#
# [4 rows x 179 columns]
#                   T_REC                    T_OBS  WAVELNTH  \
# 0  2019-12-31T23:59:35Z  2019-12-31T23:59:44.07Z       131
# 1  2019-12-31T23:59:47Z  2019-12-31T23:59:56.07Z       131
# 2  2019-12-31T23:59:59Z  2020-01-01T00:00:08.07Z       131
# 3  2020-01-01T00:00:11Z  2020-01-01T00:00:20.07Z       131
#
#                    DATE        FSN   EXPTIME  QUALITY        ORIGIN TELESCOP  \
# 0  2020-01-06T15:11:11Z  206235983  2.901336        0  SDO/JSOC-SDP  SDO/AIA
# 1  2020-01-06T15:11:11Z  206235991  2.901336        0  SDO/JSOC-SDP  SDO/AIA
# 2  2020-01-07T15:05:09Z  206235999  2.901311        0  SDO/JSOC-SDP  SDO/AIA
# 3  2020-01-07T15:05:09Z  206236007  2.901337        0  SDO/JSOC-SDP  SDO/AIA
#
#   INSTRUME  ... AGT3SVY AGT3SVZ  AGT4SVY AGT4SVZ  AIMGSHEN  \
# 0    AIA_1  ...       2      -1       60     120         4
# 1    AIA_1  ...      -1       0       57     121         4
# 2    AIA_1  ...      -3       0       56     121         4
# 3    AIA_1  ...       1       0       59     121         4
#
#                                             KEYWDDOC LVL_NUM T_REC_step  \
# 0  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 1  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 2  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 3  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
#
#                T_REC_epoch  T_REC_index
# 0  1993.01.01_00:00:04_TAI     70999201
# 1  1993.01.01_00:00:04_TAI     70999202
# 2  1993.01.01_00:00:04_TAI     70999203
# 3  1993.01.01_00:00:04_TAI     70999204
#
# [4 rows x 179 columns]
#                   T_REC                    T_OBS  WAVELNTH  \
# 0  2019-12-31T23:59:35Z  2019-12-31T23:59:46.35Z       171
# 1  2019-12-31T23:59:47Z  2019-12-31T23:59:58.35Z       171
# 2  2019-12-31T23:59:59Z  2020-01-01T00:00:10.35Z       171
# 3  2020-01-01T00:00:11Z  2020-01-01T00:00:22.35Z       171
#
#                    DATE        FSN   EXPTIME  QUALITY        ORIGIN TELESCOP  \
# 0  2020-01-06T15:11:11Z  206235984  2.000157        0  SDO/JSOC-SDP  SDO/AIA
# 1  2020-01-06T15:11:11Z  206235992  2.000141        0  SDO/JSOC-SDP  SDO/AIA
# 2  2020-01-07T15:05:09Z  206236000  2.000154        0  SDO/JSOC-SDP  SDO/AIA
# 3  2020-01-07T15:05:09Z  206236008  2.000138        0  SDO/JSOC-SDP  SDO/AIA
#
#   INSTRUME  ... AGT3SVY AGT3SVZ  AGT4SVY AGT4SVZ  AIMGSHEN  \
# 0    AIA_3  ...       1       0       59     121        13
# 1    AIA_3  ...       0       0       58     121        13
# 2    AIA_3  ...      -1       0       57     121        13
# 3    AIA_3  ...       2       0       60     122        13
#
#                                             KEYWDDOC LVL_NUM T_REC_step  \
# 0  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 1  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 2  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 3  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
#
#                T_REC_epoch  T_REC_index
# 0  1993.01.01_00:00:04_TAI     70999201
# 1  1993.01.01_00:00:04_TAI     70999202
# 2  1993.01.01_00:00:04_TAI     70999203
# 3  1993.01.01_00:00:04_TAI     70999204
#
# [4 rows x 179 columns]
#                   T_REC                    T_OBS  WAVELNTH  \
# 0  2019-12-31T23:59:35Z  2019-12-31T23:59:41.84Z       193
# 1  2019-12-31T23:59:47Z  2019-12-31T23:59:53.84Z       193
# 2  2019-12-31T23:59:59Z  2020-01-01T00:00:05.84Z       193
# 3  2020-01-01T00:00:11Z  2020-01-01T00:00:17.84Z       193
#
#                    DATE        FSN   EXPTIME  QUALITY        ORIGIN TELESCOP  \
# 0  2020-01-06T15:11:11Z  206235981  2.000044        0  SDO/JSOC-SDP  SDO/AIA
# 1  2020-01-06T15:11:11Z  206235989  2.000041        0  SDO/JSOC-SDP  SDO/AIA
# 2  2020-01-07T15:05:09Z  206235997  2.000073        0  SDO/JSOC-SDP  SDO/AIA
# 3  2020-01-07T15:05:09Z  206236005  2.000041        0  SDO/JSOC-SDP  SDO/AIA
#
#   INSTRUME  ... AGT3SVY AGT3SVZ  AGT4SVY AGT4SVZ  AIMGSHEN  \
# 0    AIA_2  ...       0       0       58     121        13
# 1    AIA_2  ...      -1       1       58     122        13
# 2    AIA_2  ...       2       0       60     121        12
# 3    AIA_2  ...       1       0       59     121        13
#
#                                             KEYWDDOC LVL_NUM T_REC_step  \
# 0  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 1  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 2  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 3  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
#
#                T_REC_epoch  T_REC_index
# 0  1993.01.01_00:00:04_TAI     70999201
# 1  1993.01.01_00:00:04_TAI     70999202
# 2  1993.01.01_00:00:04_TAI     70999203
# 3  1993.01.01_00:00:04_TAI     70999204
#
# [4 rows x 179 columns]
#                   T_REC                    T_OBS  WAVELNTH  \
# 0  2019-12-31T23:59:35Z  2019-12-31T23:59:35.08Z       211
# 1  2019-12-31T23:59:47Z  2019-12-31T23:59:47.08Z       211
# 2  2019-12-31T23:59:59Z  2019-12-31T23:59:59.08Z       211
# 3  2020-01-01T00:00:11Z  2020-01-01T00:00:11.08Z       211
#
#                    DATE        FSN   EXPTIME  QUALITY        ORIGIN TELESCOP  \
# 0  2020-01-06T15:11:11Z  206235977  2.900768        0  SDO/JSOC-SDP  SDO/AIA
# 1  2020-01-06T15:11:11Z  206235985  2.900769        0  SDO/JSOC-SDP  SDO/AIA
# 2  2020-01-06T15:11:11Z  206235993  2.900796        0  SDO/JSOC-SDP  SDO/AIA
# 3  2020-01-07T15:05:09Z  206236001  2.900769        0  SDO/JSOC-SDP  SDO/AIA
#
#   INSTRUME  ... AGT3SVY AGT3SVZ  AGT4SVY AGT4SVZ  AIMGSHEN  \
# 0    AIA_2  ...       0       0       59     121         4
# 1    AIA_2  ...       0       0       59     122         4
# 2    AIA_2  ...       2       0       60     121         4
# 3    AIA_2  ...       0      -1       58     121         4
#
#                                             KEYWDDOC LVL_NUM T_REC_step  \
# 0  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 1  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 2  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 3  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
#
#                T_REC_epoch  T_REC_index
# 0  1993.01.01_00:00:04_TAI     70999201
# 1  1993.01.01_00:00:04_TAI     70999202
# 2  1993.01.01_00:00:04_TAI     70999203
# 3  1993.01.01_00:00:04_TAI     70999204
#
# [4 rows x 179 columns]
#                   T_REC                    T_OBS  WAVELNTH  \
# 0  2019-12-31T23:59:35Z  2019-12-31T23:59:42.58Z       304
# 1  2019-12-31T23:59:47Z  2019-12-31T23:59:54.58Z       304
# 2  2019-12-31T23:59:59Z  2020-01-01T00:00:06.58Z       304
# 3  2020-01-01T00:00:11Z  2020-01-01T00:00:18.58Z       304
#
#                    DATE        FSN   EXPTIME  QUALITY        ORIGIN TELESCOP  \
# 0  2020-01-06T15:11:11Z  206235982  2.902043        0  SDO/JSOC-SDP  SDO/AIA
# 1  2020-01-06T15:11:11Z  206235990  2.902041        0  SDO/JSOC-SDP  SDO/AIA
# 2  2020-01-07T15:05:09Z  206235998  2.902044        0  SDO/JSOC-SDP  SDO/AIA
# 3  2020-01-07T15:05:09Z  206236006  2.902045        0  SDO/JSOC-SDP  SDO/AIA
#
#   INSTRUME  ... AGT3SVY AGT3SVZ  AGT4SVY AGT4SVZ  AIMGSHEN  \
# 0    AIA_4  ...      -1       0       57     121        12
# 1    AIA_4  ...      -1       0       58     121        12
# 2    AIA_4  ...       1       0       59     121        12
# 3    AIA_4  ...       1      -1       59     120        12
#
#                                             KEYWDDOC LVL_NUM T_REC_step  \
# 0  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 1  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 2  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 3  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
#
#                T_REC_epoch  T_REC_index
# 0  1993.01.01_00:00:04_TAI     70999201
# 1  1993.01.01_00:00:04_TAI     70999202
# 2  1993.01.01_00:00:04_TAI     70999203
# 3  1993.01.01_00:00:04_TAI     70999204
#
# [4 rows x 179 columns]
#                   T_REC                    T_OBS  WAVELNTH  \
# 0  2019-12-31T23:59:35Z  2019-12-31T23:59:38.08Z       335
# 1  2019-12-31T23:59:47Z  2019-12-31T23:59:50.08Z       335
# 2  2019-12-31T23:59:59Z  2020-01-01T00:00:02.09Z       335
# 3  2020-01-01T00:00:11Z  2020-01-01T00:00:14.09Z       335
#
#                    DATE        FSN   EXPTIME  QUALITY        ORIGIN TELESCOP  \
# 0  2020-01-06T15:11:11Z  206235979  2.900816        0  SDO/JSOC-SDP  SDO/AIA
# 1  2020-01-06T15:11:11Z  206235987  2.900818        0  SDO/JSOC-SDP  SDO/AIA
# 2  2020-01-07T15:05:09Z  206235995  2.900793        0  SDO/JSOC-SDP  SDO/AIA
# 3  2020-01-07T15:05:09Z  206236003  2.900820        0  SDO/JSOC-SDP  SDO/AIA
#
#   INSTRUME  ... AGT3SVY AGT3SVZ  AGT4SVY AGT4SVZ  AIMGSHEN  \
# 0    AIA_1  ...       0       0       58     122        13
# 1    AIA_1  ...      -1       0       58     121        13
# 2    AIA_1  ...      -2       1       56     122        13
# 3    AIA_1  ...       0       0       59     121        13
#
#                                             KEYWDDOC LVL_NUM T_REC_step  \
# 0  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 1  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 2  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
# 3  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       12.0
#
#                T_REC_epoch  T_REC_index
# 0  1993.01.01_00:00:04_TAI     70999201
# 1  1993.01.01_00:00:04_TAI     70999202
# 2  1993.01.01_00:00:04_TAI     70999203
# 3  1993.01.01_00:00:04_TAI     70999204
#
# [4 rows x 179 columns]

# %%
euv_header['T_REC']
# Out:
# 0    2019-12-31T23:59:35Z
# 1    2019-12-31T23:59:47Z
# 2    2019-12-31T23:59:59Z
# 3    2020-01-01T00:00:11Z
# Name: T_REC, dtype: object

# %%
import pandas as pd

# %%
date_str = euv_header['T_REC'].replace('MISSING', '').str.replace('60', '59')  # fix date format
date_diff = (pd.to_datetime(date_str).dt.tz_localize(None) - date).abs()
# sort and filter
euv_header['date_diff'] = date_diff
euv_header = euv_header.sort_values('date_diff')
euv_segment['date_diff'] = date_diff
euv_segment = euv_segment.sort_values('date_diff')
cond_tmp = euv_header.QUALITY == 0
euv_header = euv_header[cond_tmp]
euv_segment = euv_segment[cond_tmp]
# Out:
# /tmp/ipykernel_120243/1003477366.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   euv_header['date_diff'] = date_diff

# %%
euv_header[['T_REC', 'date_diff']]
# Out:
#                   T_REC       date_diff
# 2  2019-12-31T23:59:59Z 0 days 00:00:01
# 3  2020-01-01T00:00:11Z 0 days 00:00:11
# 1  2019-12-31T23:59:47Z 0 days 00:00:13
# 0  2019-12-31T23:59:35Z 0 days 00:00:25

# %%
euv_header.iloc[0]
# Out:
# T_REC             2019-12-31T23:59:59Z
# T_OBS          2020-01-01T00:00:02.09Z
# WAVELNTH                           335
# DATE              2020-01-07T15:05:09Z
# FSN                          206235995
#                         ...
# LVL_NUM                            1.0
# T_REC_step                        12.0
# T_REC_epoch    1993.01.01_00:00:04_TAI
# T_REC_index                   70999203
# date_diff              0 days 00:00:01
# Name: 2, Length: 180, dtype: object

# %%
header = euv_header.iloc[0].to_dict()
header['T_REC']
# Out:
# '2019-12-31T23:59:59Z'

# %%
segment = euv_segment.image.iloc[0]
segment
# Out:
# '/SUM46/D1248942731/S00000/image_lev1.fits'

# %%
from urllib import request

# %%
request.urlretrieve('http://jsoc.stanford.edu' + segment, 'b.fits')

from astropy.io import fits

header['DATE_OBS'] = header['DATE__OBS']
from sunpy.io._fits import header_to_fits
from sunpy.util import MetaDict
header = header_to_fits(MetaDict(header))
with fits.open('a.fits', 'update') as f:
    hdr = f[1].header
    for k, v in header.items():
        if pd.isna(v):
            continue
        hdr[k] = v
    f.verify('silentfix')

# %%
from sunpy.map import Map

# %%
Map('b.fits')
# Out:
# <sunpy.map.sources.sdo.AIAMap object>
# SunPy Map
# ---------
# Observatory:		 SDO
# Instrument:		 AIA 1
# Detector:		 AIA
# Measurement:		 335.0 Angstrom
# Wavelength:		 335.0 Angstrom
# Observation Date:	 2020-01-01 00:00:00
# Exposure Time:		 2.900793 s
# Dimension:		 [4096. 4096.] pix
# Coordinate System:	 helioprojective
# Scale:			 [0.600737 0.600737] arcsec / pix
# Reference Pixel:	 [2040.189697 2037.622925] pix
# Reference Coord:	 [0. 0.] arcsec
# array([[ 2.,  0.,  0., ..., -1.,  0.,  1.],
#        [-1.,  0., -1., ...,  1., -2.,  1.],
#        [ 0.,  0., -1., ...,  1.,  0., -2.],
#        ...,
#        [ 0.,  1.,  3., ...,  0., -1.,  1.],
#        [-1., -1.,  0., ...,  1.,  1.,  0.],
#        [-2., -1.,  0., ...,  1.,  1.,  1.]], dtype=float32)

# %%
result = Fido.search(
    a.Time('2020-01-01T00:00:00', '2020-01-01T00:00:05'),
    a.jsoc.Series('aia.lev1_euv_12s'),
    a.jsoc.Segment('image'),
    a.Wavelength(335*u.AA),
    a.jsoc.Notify("mgjeon@khu.ac.kr")
)

# %%
result.show()
# Out:
# <sunpy.net.fido_factory.UnifiedResponse object>
# Results from 1 Provider:
#
# 1 Results from the JSOCClient:
# Source: http://jsoc.stanford.edu
#
#        T_REC         ...                   image
# -------------------- ... -----------------------------------------
# 2019-12-31T23:59:59Z ... /SUM46/D1248942731/S00000/image_lev1.fits

# %%
dl_file = Fido.fetch(result)
# Out:
# 2024-10-22 22:10:03 - drms - INFO: Export request pending. [id=JSOC_20241022_001383, status=2]
# 2024-10-22 22:10:03 - drms - INFO: Waiting for 0 seconds...
# 2024-10-22 22:10:06 - sunpy - INFO: 1 URLs found for download. Full request totaling 7MB
# INFO: 1 URLs found for download. Full request totaling 7MB [sunpy.net.jsoc.jsoc]
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]

# %%
Map(dl_file[0])
# Out:
# <sunpy.map.sources.sdo.AIAMap object>
# SunPy Map
# ---------
# Observatory:		 SDO
# Instrument:		 AIA 1
# Detector:		 AIA
# Measurement:		 335.0 Angstrom
# Wavelength:		 335.0 Angstrom
# Observation Date:	 2020-01-01 00:00:00
# Exposure Time:		 2.9007929999999997 s
# Dimension:		 [4096. 4096.] pix
# Coordinate System:	 helioprojective
# Scale:			 [0.60073698 0.60073698] arcsec / pix
# Reference Pixel:	 [2040.1897  2037.62292] pix
# Reference Coord:	 [0. 0.] arcsec
# array([[ 2.,  0.,  0., ..., -1.,  0.,  1.],
#        [-1.,  0., -1., ...,  1., -2.,  1.],
#        [ 0.,  0., -1., ...,  1.,  0., -2.],
#        ...,
#        [ 0.,  1.,  3., ...,  0., -1.,  1.],
#        [-1., -1.,  0., ...,  1.,  1.,  0.],
#        [-2., -1.,  0., ...,  1.,  1.,  1.]], dtype=float32)

# %%
import numpy as np

# %%
np.allclose(Map('b.fits').data, Map(dl_file[0]).data)
# Out:
# True

# %% [markdown]
# ### UV

# %%
ds_uv = 'aia.lev1_uv_24s[%s][%s]{image}' % (time_param, ','.join(['1600', '1700']))
ds_uv
# Out:
# 'aia.lev1_uv_24s[2020-01-01_00:00:00Z][1600,1700]{image}'

# %%
keys = client.keys(ds_uv)
header, segment = client.query(ds_uv, key=','.join(keys), seg='image')

# %%
header
# Out:
#                   T_REC                    T_OBS  WAVELNTH  \
# 0  2019-12-31T23:59:47Z  2019-12-31T23:59:51.58Z      1600
#
#                    DATE        FSN   EXPTIME  QUALITY        ORIGIN TELESCOP  \
# 0  2020-01-06T15:11:13Z  206235988  2.900738        0  SDO/JSOC-SDP  SDO/AIA
#
#   INSTRUME  ... AGT3SVY AGT3SVZ  AGT4SVY AGT4SVZ  AIMGSHEN  \
# 0    AIA_3  ...      -3       0       55     121         4
#
#                                             KEYWDDOC LVL_NUM T_REC_step  \
# 0  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       24.0
#
#                T_REC_epoch  T_REC_index
# 0  1993.01.01_00:00:04_TAI     35499601
#
# [1 rows x 179 columns]

# %%
t = date - timedelta(seconds=48)
t
# Out:
# datetime.datetime(2019, 12, 31, 23, 59, 12)

# %%
t.isoformat('_', timespec='seconds')
# Out:
# '2019-12-31_23:59:12'

# %%
(t + timedelta(seconds=96)).isoformat('_', timespec='seconds')
# Out:
# '2020-01-01_00:00:48'

# %%
for wl in ['1600', '1700']:
    uv_ds = 'aia.lev1_uv_24s[%sZ/96s][%s]{image}' % (
                    t.replace(tzinfo=None).isoformat('_', timespec='seconds'), wl)
    uv_keys = client.keys(uv_ds)
    uv_header, uv_segment = client.query(uv_ds, key=','.join(uv_keys), seg='image')
    print(uv_header)
# Out:
#                   T_REC                    T_OBS  WAVELNTH  \
# 0  2019-12-31T23:58:59Z  2019-12-31T23:59:03.58Z      1600
# 1  2019-12-31T23:59:23Z  2019-12-31T23:59:27.58Z      1600
# 2  2019-12-31T23:59:47Z  2019-12-31T23:59:51.58Z      1600
# 3  2020-01-01T00:00:11Z  2020-01-01T00:00:15.58Z      1600
#
#                    DATE        FSN   EXPTIME  QUALITY        ORIGIN TELESCOP  \
# 0  2020-01-06T15:11:13Z  206235956  2.900735        0  SDO/JSOC-SDP  SDO/AIA
# 1  2020-01-06T15:11:13Z  206235972  2.900736        0  SDO/JSOC-SDP  SDO/AIA
# 2  2020-01-06T15:11:13Z  206235988  2.900738        0  SDO/JSOC-SDP  SDO/AIA
# 3  2020-01-07T15:05:20Z  206236004  2.900735        0  SDO/JSOC-SDP  SDO/AIA
#
#   INSTRUME  ... AGT3SVY AGT3SVZ  AGT4SVY AGT4SVZ  AIMGSHEN  \
# 0    AIA_3  ...       3       0       61     122         4
# 1    AIA_3  ...       0       1       58     122         4
# 2    AIA_3  ...      -3       0       55     121         4
# 3    AIA_3  ...       2       1       60     122         4
#
#                                             KEYWDDOC LVL_NUM T_REC_step  \
# 0  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       24.0
# 1  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       24.0
# 2  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       24.0
# 3  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       24.0
#
#                T_REC_epoch  T_REC_index
# 0  1993.01.01_00:00:04_TAI     35499599
# 1  1993.01.01_00:00:04_TAI     35499600
# 2  1993.01.01_00:00:04_TAI     35499601
# 3  1993.01.01_00:00:04_TAI     35499602
#
# [4 rows x 179 columns]
#                   T_REC                    T_OBS  WAVELNTH  \
# 0  2019-12-31T23:58:59Z  2019-12-31T23:59:17.22Z      1700
# 1  2019-12-31T23:59:23Z  2019-12-31T23:59:41.22Z      1700
# 2  2020-01-01T00:00:11Z  2020-01-01T00:00:29.22Z      1700
#
#                    DATE        FSN   EXPTIME  QUALITY        ORIGIN TELESCOP  \
# 0  2020-01-06T15:11:13Z  206235964  1.000014        0  SDO/JSOC-SDP  SDO/AIA
# 1  2020-01-06T15:11:13Z  206235980  1.000014        0  SDO/JSOC-SDP  SDO/AIA
# 2  2020-01-07T15:05:20Z  206236012  1.000018        0  SDO/JSOC-SDP  SDO/AIA
#
#   INSTRUME  ... AGT3SVY AGT3SVZ  AGT4SVY AGT4SVZ  AIMGSHEN  \
# 0    AIA_3  ...      -1       0       58     121         4
# 1    AIA_3  ...       1       1       59     122         4
# 2    AIA_3  ...       1       0       59     122         4
#
#                                             KEYWDDOC LVL_NUM T_REC_step  \
# 0  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       24.0
# 1  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       24.0
# 2  https://www.lmsal.com/sdodocs/doc?cmd=dcur&pro...     1.0       24.0
#
#                T_REC_epoch  T_REC_index
# 0  1993.01.01_00:00:04_TAI     35499599
# 1  1993.01.01_00:00:04_TAI     35499600
# 2  1993.01.01_00:00:04_TAI     35499602
#
# [3 rows x 179 columns]

# %%
uv_header['T_REC']
# Out:
# 0    2019-12-31T23:58:59Z
# 1    2019-12-31T23:59:23Z
# 2    2020-01-01T00:00:11Z
# Name: T_REC, dtype: object

# %%
date_str = uv_header['T_REC'].replace('MISSING', '').str.replace('60', '59')  # fix date format
date_diff = (pd.to_datetime(date_str).dt.tz_localize(None) - date).abs()
# sort and filter
uv_header['date_diff'] = date_diff
uv_header = uv_header.sort_values('date_diff')
uv_header['date_diff'] = date_diff
uv_header = uv_header.sort_values('date_diff')
cond_tmp = uv_header.QUALITY == 0
uv_header = uv_header[cond_tmp]
uv_header = uv_header[cond_tmp]
# Out:
# /tmp/ipykernel_120243/702363636.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   uv_header['date_diff'] = date_diff

# %%
uv_header[['T_REC', 'date_diff']]
# Out:
#                   T_REC       date_diff
# 2  2020-01-01T00:00:11Z 0 days 00:00:11
# 1  2019-12-31T23:59:23Z 0 days 00:00:37
# 0  2019-12-31T23:58:59Z 0 days 00:01:01

# %%
uv_header.iloc[0]
# Out:
# T_REC             2020-01-01T00:00:11Z
# T_OBS          2020-01-01T00:00:29.22Z
# WAVELNTH                          1700
# DATE              2020-01-07T15:05:20Z
# FSN                          206236012
#                         ...
# LVL_NUM                            1.0
# T_REC_step                        24.0
# T_REC_epoch    1993.01.01_00:00:04_TAI
# T_REC_index                   35499602
# date_diff              0 days 00:00:11
# Name: 2, Length: 180, dtype: object

# %% [markdown]
# ### HMI

# %%
ds_hmi = 'hmi.M_720s[%s]{magnetogram}' % time_param
ds_hmi
# Out:
# 'hmi.M_720s[2020-01-01_00:00:00Z]{magnetogram}'

# %%
keys_hmi = client.keys(ds_hmi)
header_hmi, segment_hmi = client.query(ds_hmi, key=','.join(keys_hmi), seg='magnetogram')

# %%
header_hmi
# Out:
#     cparms_sg000  magnetogram_bzero  magnetogram_bscale                  DATE  \
# 0  compress Rice                  0                 0.1  2020-01-05T23:20:55Z
#
#                  DATE__OBS                 DATE-OBS TELESCOP      INSTRUME  \
# 0  2019-12-31T23:58:29.60Z  2019-12-31T23:58:29.60Z  SDO/HMI  HMI_COMBINED
#
#    WAVELNTH  CAMERA  ...                                            ROTCOEF  \
# 0    6173.0       3  ...  /home/jsoc/cvs/Development/JSOC/proj/lev1.5_hm...
#
#   ODICOEFF OROCOEFF  POLCALM  \
# 0        6        4        1
#
#                                             CODEVER0  \
# 0  $Id: HMI_IQUV_averaging.c,v 1.57 2018/08/31 22...
#
#                                             CODEVER1  \
# 0  $Id: interpol_code.c,v 1.6 2017/08/31 22:17:13...
#
#                                             CODEVER2  \
# 0  $Id: interpol_code.c,v 1.6 2017/08/31 22:17:13...
#
#                                             CODEVER3  T_REC_index CALVER64
# 0  $Id: polcal.c,v 1.8 2016/10/03 19:11:21 arta E...      1183320   270610
#
# [1 rows x 91 columns]

# %%
np.all(len(header_hmi) != 1 or header_hmi.QUALITY != 0)
# Out:
# False

# %%
# Out:
# 0    False
# Name: QUALITY, dtype: bool

# %%
segment_hmi
# Out:
#                                   magnetogram
# 0  /SUM30/D1249158085/S00003/magnetogram.fits

# %%
720*2
# Out:
# 1440

# %%
t = date - timedelta(minutes=24)
t
# Out:
# datetime.datetime(2019, 12, 31, 23, 36)

# %%
t.isoformat('_', timespec='seconds')
# Out:
# '2019-12-31_23:36:00'

# %%
(t + timedelta(minutes=48)).isoformat('_', timespec='seconds')
# Out:
# '2020-01-01_00:24:00'

# %%
hmi_ds = 'hmi.M_720s[%sZ/48m]{magnetogram}' % t.replace(tzinfo=None).isoformat('_', timespec='seconds')
hmi_keys = client.keys(hmi_ds)
header_hmi, segment_hmi = client.query(hmi_ds, key=','.join(keys_hmi), seg='magnetogram')

# %%
header_hmi["T_REC"]
# Out:
# 0    2019.12.31_23:36:00_TAI
# 1    2019.12.31_23:48:00_TAI
# 2    2020.01.01_00:00:00_TAI
# 3    2020.01.01_00:12:00_TAI
# Name: T_REC, dtype: object

# %%
date_str = header_hmi['T_REC'].str.replace('_TAI', '').str.replace('_', 'T')
date_str
# Out:
# 0    2019.12.31T23:36:00
# 1    2019.12.31T23:48:00
# 2    2020.01.01T00:00:00
# 3    2020.01.01T00:12:00
# Name: T_REC, dtype: object

# %%
date_diff = (pd.to_datetime(date_str).dt.tz_localize(None) - date).abs()
# sort and filter
header_hmi['date_diff'] = date_diff
header_hmi = header_hmi.sort_values('date_diff')
segment_hmi['date_diff'] = date_diff
segment_hmi = segment_hmi.sort_values('date_diff')
cond_tmp = header_hmi.QUALITY == 0
header_hmi = header_hmi[cond_tmp]
segment_hmi = segment_hmi[cond_tmp]

# %%
header_hmi[['T_REC', 'date_diff']]
# Out:
#                      T_REC       date_diff
# 2  2020.01.01_00:00:00_TAI 0 days 00:00:00
# 1  2019.12.31_23:48:00_TAI 0 days 00:12:00
# 3  2020.01.01_00:12:00_TAI 0 days 00:12:00
# 0  2019.12.31_23:36:00_TAI 0 days 00:24:00

# %%
header_hmi["WAVELNTH"]
# Out:
# 2    6173.0
# 1    6173.0
# 3    6173.0
# 0    6173.0
# Name: WAVELNTH, dtype: float64

# %%
segment_hmi
# Out:
#                                   magnetogram       date_diff
# 2  /SUM30/D1249158085/S00003/magnetogram.fits 0 days 00:00:00
# 1  /SUM30/D1249158085/S00002/magnetogram.fits 0 days 00:12:00
# 3  /SUM30/D1249158085/S00004/magnetogram.fits 0 days 00:12:00
# 0  /SUM30/D1249158085/S00001/magnetogram.fits 0 days 00:24:00

# %%
header = header_hmi.iloc[0].to_dict()

# %%
segment = segment_hmi.iloc[0].magnetogram
segment
# Out:
# '/SUM30/D1249158085/S00003/magnetogram.fits'

# %%
from urllib import request

# %%
header['T_REC']
# Out:
# '2020.01.01_00:00:00_TAI'

# %%
request.urlretrieve('http://jsoc.stanford.edu' + segment, 'a.fits')

from astropy.io import fits

header['DATE_OBS'] = header['DATE__OBS']
from sunpy.io._fits import header_to_fits
from sunpy.util import MetaDict
header = header_to_fits(MetaDict(header))
with fits.open('a.fits', 'update') as f:
    hdr = f[1].header
    for k, v in header.items():
        if pd.isna(v):
            continue
        hdr[k] = v
    f.verify('silentfix')
# Out:
# WARNING: SunpyMetadataWarning: The meta key cparms_sg000 is too long, dropping from the FITS header (maximum allowed key length is 8 characters). [sunpy.io._fits]
# 2024-10-22 22:13:42 - sunpy - WARNING: SunpyMetadataWarning: The meta key cparms_sg000 is too long, dropping from the FITS header (maximum allowed key length is 8 characters).
# WARNING: SunpyMetadataWarning: The meta key magnetogram_bzero is too long, dropping from the FITS header (maximum allowed key length is 8 characters). [sunpy.io._fits]
# 2024-10-22 22:13:42 - sunpy - WARNING: SunpyMetadataWarning: The meta key magnetogram_bzero is too long, dropping from the FITS header (maximum allowed key length is 8 characters).
# WARNING: SunpyMetadataWarning: The meta key magnetogram_bscale is too long, dropping from the FITS header (maximum allowed key length is 8 characters). [sunpy.io._fits]
# 2024-10-22 22:13:42 - sunpy - WARNING: SunpyMetadataWarning: The meta key magnetogram_bscale is too long, dropping from the FITS header (maximum allowed key length is 8 characters).
# WARNING: SunpyMetadataWarning: The meta key date__obs is too long, dropping from the FITS header (maximum allowed key length is 8 characters). [sunpy.io._fits]
# 2024-10-22 22:13:42 - sunpy - WARNING: SunpyMetadataWarning: The meta key date__obs is too long, dropping from the FITS header (maximum allowed key length is 8 characters).
# WARNING: SunpyMetadataWarning: The meta key crder1 has a NaN value, which is not valid in a FITS header, dropping from the FITS header [sunpy.io._fits]
# 2024-10-22 22:13:42 - sunpy - WARNING: SunpyMetadataWarning: The meta key crder1 has a NaN value, which is not valid in a FITS header, dropping from the FITS header
# WARNING: SunpyMetadataWarning: The meta key crder2 has a NaN value, which is not valid in a FITS header, dropping from the FITS header [sunpy.io._fits]
# 2024-10-22 22:13:42 - sunpy - WARNING: SunpyMetadataWarning: The meta key crder2 has a NaN value, which is not valid in a FITS header, dropping from the FITS header
# WARNING: SunpyMetadataWarning: The meta key csyser1 has a NaN value, which is not valid in a FITS header, dropping from the FITS header [sunpy.io._fits]
# 2024-10-22 22:13:42 - sunpy - WARNING: SunpyMetadataWarning: The meta key csyser1 has a NaN value, which is not valid in a FITS header, dropping from the FITS header
# WARNING: SunpyMetadataWarning: The meta key csyser2 has a NaN value, which is not valid in a FITS header, dropping from the FITS header [sunpy.io._fits]
# 2024-10-22 22:13:42 - sunpy - WARNING: SunpyMetadataWarning: The meta key csyser2 has a NaN value, which is not valid in a FITS header, dropping from the FITS header
# WARNING: SunpyMetadataWarning: The meta key t_rec_epoch is too long, dropping from the FITS header (maximum allowed key length is 8 characters). [sunpy.io._fits]
# 2024-10-22 22:13:42 - sunpy - WARNING: SunpyMetadataWarning: The meta key t_rec_epoch is too long, dropping from the FITS header (maximum allowed key length is 8 characters).
# WARNING: SunpyMetadataWarning: The meta key t_rec_step is too long, dropping from the FITS header (maximum allowed key length is 8 characters). [sunpy.io._fits]
# 2024-10-22 22:13:42 - sunpy - WARNING: SunpyMetadataWarning: The meta key t_rec_step is too long, dropping from the FITS header (maximum allowed key length is 8 characters).
# WARNING: SunpyMetadataWarning: The meta key t_rec_unit is too long, dropping from the FITS header (maximum allowed key length is 8 characters). [sunpy.io._fits]
# 2024-10-22 22:13:42 - sunpy - WARNING: SunpyMetadataWarning: The meta key t_rec_unit is too long, dropping from the FITS header (maximum allowed key length is 8 characters).
# WARNING: SunpyMetadataWarning: The meta key t_rec_index is too long, dropping from the FITS header (maximum allowed key length is 8 characters). [sunpy.io._fits]
# 2024-10-22 22:13:42 - sunpy - WARNING: SunpyMetadataWarning: The meta key t_rec_index is too long, dropping from the FITS header (maximum allowed key length is 8 characters).
# WARNING: SunpyMetadataWarning: The meta key date_diff is too long, dropping from the FITS header (maximum allowed key length is 8 characters). [sunpy.io._fits]
# 2024-10-22 22:13:42 - sunpy - WARNING: SunpyMetadataWarning: The meta key date_diff is too long, dropping from the FITS header (maximum allowed key length is 8 characters).

# %%
from sunpy.map import Map

# %%
Map('a.fits')
# Out:
# <sunpy.map.sources.sdo.HMIMap object>
# SunPy Map
# ---------
# Observatory:		 SDO
# Instrument:		 HMI COMBINED
# Detector:		 HMI
# Measurement:		 magnetogram
# Wavelength:		 6173.0
# Observation Date:	 2019-12-31 23:58:29
# Exposure Time:		 Unknown
# Dimension:		 [4096. 4096.] pix
# Coordinate System:	 helioprojective
# Scale:			 [0.504013 0.504013] arcsec / pix
# Reference Pixel:	 [2041.215576 2044.104248] pix
# Reference Coord:	 [0. 0.] arcsec
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])

# %%
res = Fido.search(
    a.Time('2020-01-01T00:00:00', '2020-01-01T00:01:00'),
    a.jsoc.Series('hmi.M_720s'),
    a.jsoc.Segment('magnetogram'),
    a.jsoc.Notify("mgjeon@khu.ac.kr")
)

# %%
dl_files = Fido.fetch(res)
# Out:
# 2024-10-22 22:06:51 - drms - INFO: Export request pending. [id=JSOC_20241022_001511, status=2]
# 2024-10-22 22:06:51 - drms - INFO: Waiting for 0 seconds...
# 2024-10-22 22:06:52 - sunpy - INFO: 1 URLs found for download. Full request totaling 14MB
# INFO: 1 URLs found for download. Full request totaling 14MB [sunpy.net.jsoc.jsoc]
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]

# %%
dl_files
# Out:
# <parfive.results.Results object>
# ['/home/mgj/sunpy/data/hmi.m_720s.20200101_000000_TAI.3.magnetogram.fits']

# %%
Map(dl_files[0])
# Out:
# <sunpy.map.sources.sdo.HMIMap object>
# SunPy Map
# ---------
# Observatory:		 SDO
# Instrument:		 HMI COMBINED
# Detector:		 HMI
# Measurement:		 magnetogram
# Wavelength:		 6173.0 Angstrom
# Observation Date:	 2019-12-31 23:58:29
# Exposure Time:		 Unknown
# Dimension:		 [4096. 4096.] pix
# Coordinate System:	 helioprojective
# Scale:			 [0.50401294 0.50401294] arcsec / pix
# Reference Pixel:	 [2041.21558 2044.10425] pix
# Reference Coord:	 [0. 0.] arcsec
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])

# %%
import numpy as np

# %%
np.allclose(np.nan_to_num(Map('a.fits').data), np.nan_to_num(Map(dl_files[0]).data))
# Out:
# True
